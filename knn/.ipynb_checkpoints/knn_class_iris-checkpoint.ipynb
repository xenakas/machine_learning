# %% [markdown]
# ## KNN Classifier for Iris DataSet

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.metrics
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, KFold 
from sklearn.datasets import load_iris
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.pipeline import Pipeline

# %%
iris=load_iris()
iris.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
# print(iris.DESCR)

# %%
df=pd.DataFrame(iris.data,columns=iris.feature_names)
df.head(5)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df_target=pd.DataFrame(iris.target,columns=["MEDV"])
df_target.head()
# Out:
#    MEDV
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
df_full=pd.concat([df,df_target],axis=1)
df_full.head(5)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    MEDV
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
df_full['MEDV'] = df_full['MEDV'].astype('category')

# %%
sns.set()
sns.pairplot(df_full, hue='MEDV', diag_kind="kde");
# Out:
# /home/xenakas/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /home/xenakas/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /home/xenakas/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, random_state=1)

# %% [markdown]
# ### Classification metrics

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
sc_train = knn.score(X_train , y_train)
sc_test = knn.score(X_test , y_test)
sc_train, sc_test
# Out:
# (0.9464285714285714, 1.0)

# %%
pred = knn.predict(X_test)
print(sklearn.metrics.classification_report(y_test, pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000        13
#            1     1.0000    1.0000    1.0000        16
#            2     1.0000    1.0000    1.0000         9
#
#    micro avg     1.0000    1.0000    1.0000        38
#    macro avg     1.0000    1.0000    1.0000        38
# weighted avg     1.0000    1.0000    1.0000        38

# %%
pred_proba = knn.predict_proba(X_test)
sklearn.metrics.log_loss(y_test, pred_proba)
# Out:
# 0.02134026884780017

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# #### StandardScaler

# %%
stdsc = StandardScaler()
stdsc.fit(X_train)
X_train_std = stdsc.transform(X_train)
X_test_std = stdsc.transform(X_test)

# %%
df_full_std = pd.concat([pd.DataFrame(X_train_std),pd.DataFrame(y_train)],axis=1)
df_full_std.columns = df_full.columns

# %%
sns.set()
sns.pairplot(df_full_std, hue='MEDV', diag_kind="kde");
# Out:
# /home/xenakas/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /home/xenakas/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /home/xenakas/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train_std, y_train)

sc_train = knn.score(X_train_std , y_train)
sc_test = knn.score(X_test_std , y_test)

sc_train, sc_test
# Out:
# (0.9464285714285714, 1.0)

# %%
pred = knn.predict(X_test_std)
print(sklearn.metrics.classification_report(y_test, pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000        13
#            1     1.0000    1.0000    1.0000        16
#            2     1.0000    1.0000    1.0000         9
#
#    micro avg     1.0000    1.0000    1.0000        38
#    macro avg     1.0000    1.0000    1.0000        38
# weighted avg     1.0000    1.0000    1.0000        38

# %%
pred_proba = knn.predict_proba(X_test_std)
sklearn.metrics.log_loss(y_test, pred_proba)
# Out:
# 0.03201040327169922

# %% [markdown]
# #### MinMaxScaler

# %%
mmsc = MinMaxScaler()
mmsc.fit(X_train)
X_train_mm = mmsc.transform(X_train)
X_test_mm = mmsc.transform(X_test)

# %%
df_full_mm = pd.concat([pd.DataFrame(X_train_mm),pd.DataFrame(y_train)],axis=1)
df_full_mm.columns = df_full.columns

# %%
sns.set()
sns.pairplot(df_full_mm, hue='MEDV', diag_kind="kde");
# Out:
# /home/xenakas/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /home/xenakas/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /home/xenakas/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train_mm, y_train)

sc_train = knn.score(X_train_mm , y_train)
sc_test = knn.score(X_test_mm, y_test)

sc_train, sc_test
# Out:
# (0.9553571428571429, 1.0)

# %%
pred = knn.predict(X_test_mm)
print(sklearn.metrics.classification_report(y_test, pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000        13
#            1     1.0000    1.0000    1.0000        16
#            2     1.0000    1.0000    1.0000         9
#
#    micro avg     1.0000    1.0000    1.0000        38
#    macro avg     1.0000    1.0000    1.0000        38
# weighted avg     1.0000    1.0000    1.0000        38

# %%
pred_proba = knn.predict_proba(X_test_mm)
sklearn.metrics.log_loss(y_test, pred_proba)
# Out:
# 0.01067013442390114

# %% [markdown]
# #### RobustScaler

# %%
robsc = RobustScaler()
robsc.fit(X_train)
X_train_rob = robsc.transform(X_train)
X_test_rob = robsc.transform(X_test)

# %%
df_full_rob = pd.concat([pd.DataFrame(X_train_rob),pd.DataFrame(y_train)],axis=1)
df_full_rob.columns = df_full.columns

# %%
sns.set()
sns.pairplot(df_full_rob, hue='MEDV', diag_kind="kde");
# Out:
# /home/xenakas/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /home/xenakas/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /home/xenakas/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train_rob, y_train)

sc_train = knn.score(X_train_rob , y_train)
sc_test = knn.score(X_test_rob , y_test)

sc_train, sc_test
# Out:
# (0.9375, 0.9736842105263158)

# %%
pred = knn.predict(X_test_rob)
print(sklearn.metrics.classification_report(y_test, pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000        13
#            1     1.0000    0.9375    0.9677        16
#            2     0.9000    1.0000    0.9474         9
#
#    micro avg     0.9737    0.9737    0.9737        38
#    macro avg     0.9667    0.9792    0.9717        38
# weighted avg     0.9763    0.9737    0.9740        38

# %%
pred_proba = knn.predict_proba(X_test_rob)
sklearn.metrics.log_loss(y_test, pred_proba)
# Out:
# 0.060921252973491546

# %% [markdown]
# #### Normalizer

# %%
norm = Normalizer()
norm.fit(X_train)
X_train_norm = norm.transform(X_train)
X_test_norm = norm.transform(X_test)

# %%
df_full_norm = pd.concat([pd.DataFrame(X_train_norm),pd.DataFrame(y_train)],axis=1)
df_full_norm.columns = df_full.columns

# %%
sns.set()
sns.pairplot(df_full_norm, hue='MEDV', diag_kind="kde");
# Out:
# /home/xenakas/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /home/xenakas/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /home/xenakas/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train_norm, y_train)

sc_train = knn.score(X_train_norm , y_train)
sc_test = knn.score(X_test_norm, y_test)

sc_train, sc_test
# Out:
# (0.9732142857142857, 0.9473684210526315)

# %%
pred = knn.predict(X_test_norm)
print(sklearn.metrics.classification_report(y_test, pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000        13
#            1     0.9375    0.9375    0.9375        16
#            2     0.8889    0.8889    0.8889         9
#
#    micro avg     0.9474    0.9474    0.9474        38
#    macro avg     0.9421    0.9421    0.9421        38
# weighted avg     0.9474    0.9474    0.9474        38

# %%
pred_proba = knn.predict_proba(X_test_norm)
sklearn.metrics.log_loss(y_test, pred_proba)
# Out:
# 0.1218425059469809

# %% [markdown]
# #### Вывод
# Наилучшие результаты получаются при использовании __MinMaxScaler__

# %% [markdown]
# ### Finding the best combination of hyperparameters

# %%
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, random_state=1)

# %%
pipe = Pipeline([('preprocessing', MinMaxScaler()), 
                 ('classifier', KNeighborsClassifier())])

param_grid = { 
               'preprocessing': [MinMaxScaler(), StandardScaler(),RobustScaler(), Normalizer(), None], 
               'classifier': [KNeighborsClassifier()],
               'classifier__n_neighbors': [int(x) for x in np.linspace(start = 1, stop = 10, num = 10)],
               'classifier__p': [1, 2, 3, 4, 6, 8, 10],
               'classifier__weights': ['uniform', 'distance'],
               'classifier__algorithm' : ['auto', 'ball_tree', 'kd_tree', 'brute']
             }

kfold = KFold(n_splits=10, shuffle=True, random_state=42)

# %%
grid = GridSearchCV(pipe, param_grid, cv=kfold, return_train_score=True, iid=True)
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=42, shuffle=True),
#        error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('preprocessing', MinMaxScaler(copy=True, feature_range=(0, 1))), ('classifier', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))]),
#        fit_params=None, iid=True, n_jobs=None,
#        param_grid={'preprocessing': [MinMaxScaler(copy=True, feature_range=(0, 1)), StandardScaler(copy=True, with_mean=True, with_std=True), RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#        with_scaling=True), Normalizer(copy=True, norm='l2'), None], 'classifier': [KNeighbo...ights': ['uniform', 'distance'], 'classifier__algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=0)

# %%
print("----------------- Обучили и тестировали -------------------")
print("Наилучшие параметры:\n{}\n".format(grid.best_params_))
print("Средняя правильность для наилучшей модели кроссвалидации на валидационных тестовых наборах: {:.6f}\n".format(grid.best_score_)) 
print("Правильность для наилучшей модели на тестовом наборе: {:.6f}\n".format(grid.score(X_test, y_test)))
gridresults = pd.DataFrame(grid.cv_results_)
display(gridresults.sort_values(["rank_test_score"]).T)
# Out:
# ----------------- Обучили и тестировали -------------------
# Наилучшие параметры:
# {'classifier': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#            weights='uniform'), 'classifier__algorithm': 'auto', 'classifier__n_neighbors': 7, 'classifier__p': 2, 'classifier__weights': 'uniform', 'preprocessing': MinMaxScaler(copy=True, feature_range=(0, 1))}
#
# Средняя правильность для наилучшей модели кроссвалидации на валидационных тестовых наборах: 0.973214
#
# Правильность для наилучшей модели на тестовом наборе: 1.000000
#                                                                             628   \
# mean_fit_time                                                        0.000849485
# std_fit_time                                                         0.000242013
# mean_score_time                                                       0.00126202
# std_score_time                                                       7.60076e-05
# param_classifier               KNeighborsClassifier(algorithm='auto', leaf_si...
# param_classifier__algorithm                                                 auto
# param_classifier__n_neighbors                                                  9
# param_classifier__p                                                           10
# param_classifier__weights                                               distance
# param_preprocessing                             Normalizer(copy=True, norm='l2')
# params                         {'classifier': KNeighborsClassifier(algorithm=...
# split0_test_score                                                       0.916667
# split1_test_score                                                              1
# split2_test_score                                                              1
# split3_test_score                                                              1
# split4_test_score                                                              1
# split5_test_score                                                              1
# split6_test_score                                                       0.818182
# split7_test_score                                                              1
# split8_test_score                                                              1
# split9_test_score                                                              1
# mean_test_score                                                         0.973214
# std_test_score                                                          0.057213
# rank_test_score                                                                1
# split0_train_score                                                             1
# split1_train_score                                                             1
# split2_train_score                                                             1
# split3_train_score                                                             1
# split4_train_score                                                             1
# split5_train_score                                                             1
# split6_train_score                                                             1
# split7_train_score                                                             1
# split8_train_score                                                             1
# split9_train_score                                                             1
# mean_train_score                                                               1
# std_train_score                                                                0
#
#                                                                             1279  \
# mean_fit_time                                                         0.00121377
# std_fit_time                                                         0.000352675
# mean_score_time                                                       0.00199976
# std_score_time                                                       0.000453001
# param_classifier               KNeighborsClassifier(algorithm='auto', leaf_si...
# param_classifier__algorithm                                            ball_tree
# param_classifier__n_neighbors                                                  9
# param_classifier__p                                                            2
# param_classifier__weights                                               distance
# param_preprocessing                                                         None
# params                         {'classifier': KNeighborsClassifier(algorithm=...
# split0_test_score                                                       0.916667
# split1_test_score                                                              1
# split2_test_score                                                       0.909091
# split3_test_score                                                              1
# split4_test_score                                                              1
# split5_test_score                                                              1
# split6_test_score                                                       0.909091
# split7_test_score                                                              1
# split8_test_score                                                              1
# split9_test_score                                                              1
# mean_test_score                                                         0.973214
# std_test_score                                                         0.0406196
# rank_test_score                                                                1
# split0_train_score                                                             1
# split1_train_score                                                             1
# split2_train_score                                                             1
# split3_train_score                                                             1
# split4_train_score                                                             1
# split5_train_score                                                             1
# split6_train_score                                                             1
# split7_train_score                                                             1
# split8_train_score                                                             1
# split9_train_score                                                             1
# mean_train_score                                                               1
# std_train_score                                                                0
#
#                                                                             653   \
# mean_fit_time                                                         0.00132377
# std_fit_time                                                         0.000338343
# mean_score_time                                                       0.00192251
# std_score_time                                                       0.000496037
# param_classifier               KNeighborsClassifier(algorithm='auto', leaf_si...
# param_classifier__algorithm                                                 auto
# param_classifier__n_neighbors                                                 10
# param_classifier__p                                                            3
# param_classifier__weights                                                uniform
# param_preprocessing                             Normalizer(copy=True, norm='l2')
# params                         {'classifier': KNeighborsClassifier(algorithm=...
# split0_test_score                                                       0.916667
# split1_test_score                                                              1
# split2_test_score                                                              1
# split3_test_score                                                              1
# split4_test_score                                                              1
# split5_test_score                                                              1
# split6_test_score                                                       0.818182
# split7_test_score                                                              1
# split8_test_score                                                              1
# split9_test_score                                                              1
# mean_test_score                                                         0.973214
# std_test_score                                                          0.057213
# rank_test_score                                                                1
# split0_train_score                                                          0.98
# split1_train_score                                                          0.96
# split2_train_score                                                      0.970297
# split3_train_score                                                      0.980198
# split4_train_score                                                      0.970297
# split5_train_score                                                      0.970297
# split6_train_score                                                      0.990099
# split7_train_score                                                      0.970297
# split8_train_score                                                      0.970297
# split9_train_score                                                      0.970297
# mean_train_score                                                        0.973208
# std_train_score                                                       0.00778198
#
#                                                                             649   \
# mean_fit_time                                                        0.000981665
# std_fit_time                                                         0.000168741
# mean_score_time                                                       0.00151923
# std_score_time                                                       0.000273328
# param_classifier               KNeighborsClassifier(algorithm='auto', leaf_si...
# param_classifier__algorithm                                                 auto
# param_classifier__n_neighbors                                                 10
# param_classifier__p                                                            2
# param_classifier__weights                                               distance
# param_preprocessing                                                         None
# params                         {'classifier': KNeighborsClassifier(algorithm=...
# split0_test_score                                                       0.916667
# split1_test_score                                                              1
# split2_test_score                                                       0.909091
# split3_test_score                                                              1
# split4_test_score                                                              1
# split5_test_score                                                              1
# split6_test_score                                                       0.909091
# split7_test_score                                                              1
# split8_test_score                                                              1
# split9_test_score                                                              1
# mean_test_score                                                         0.973214
# std_test_score                                                         0.0406196
# rank_test_score                                                                1
# split0_train_score                                                             1
# split1_train_score                                                             1
# split2_train_score                                                             1
# split3_train_score                                                             1
# split4_train_score                                                             1
# split5_train_score                                                             1
# split6_train_score                                                             1
# split7_train_score                                                             1
# split8_train_score                                                             1
# split9_train_score                                                             1
# mean_train_score                                                               1
# std_train_score                                                                0
#
#                                                                             648   \
# mean_fit_time                                                          0.0011622
# std_fit_time                                                         0.000286815
# mean_score_time                                                       0.00162044
# std_score_time                                                       0.000399184
# param_classifier               KNeighborsClassifier(algorithm='auto', leaf_si...
# param_classifier__algorithm                                                 auto
# param_classifier__n_neighbors                                                 10
# param_classifier__p                                                            2
# param_classifier__weights                                               distance
# param_preprocessing                             Normalizer(copy=True, norm='l2')
# params                         {'classifier': KNeighborsClassifier(algorithm=...
# split0_test_score                                                       0.916667
# split1_test_score                                                              1
# split2_test_score                                                              1
# split3_test_score                                                              1
# split4_test_score                                                              1
# split5_test_score                                                              1
# split6_test_score                                                       0.818182
# split7_test_score                                                              1
# split8_test_score                                                              1
# split9_test_score                                                              1
# mean_test_score                                                         0.973214
# std_test_score                                                          0.057213
# rank_test_score                                                                1
# split0_train_score                                                             1
# split1_train_score                                                             1
# split2_train_score                                                             1
# split3_train_score                                                             1
# split4_train_score                                                             1
# split5_train_score                                                             1
# split6_train_score                                                             1
# split7_train_score                                                             1
# split8_train_score                                                             1
# split9_train_score                                                             1
# mean_train_score                                                               1
# std_train_score                                                                0
#
#                                                                             1283  \
# mean_fit_time                                                          0.0019407
# std_fit_time                                                          0.00052292
# mean_score_time                                                       0.00311024
# std_score_time                                                        0.00045483
# param_classifier               KNeighborsClassifier(algorithm='auto', leaf_si...
# param_classifier__algorithm                                            ball_tree
# param_classifier__n_neighbors                                                  9
# param_classifier__p                                                            3
# param_classifier__weights                                                uniform
# param_preprocessing                             Normalizer(copy=True, norm='l2')
# params                         {'classifier': KNeighborsClassifier(algorithm=...
# split0_test_score                                                       0.916667
# split1_test_score                                                              1
# split2_test_score                                                              1
# split3_test_score                                                              1
# split4_test_score                                                              1
# split5_test_score                                                              1
# split6_test_score                                                       0.818182
# split7_test_score                                                              1
# split8_test_score                                                              1
# split9_test_score                                                              1
# mean_test_score                                                         0.973214
# std_test_score                                                          0.057213
# rank_test_score                                                                1
# split0_train_score                                                          0.98
# split1_train_score                                                          0.96
# split2_train_score                                                      0.970297
# split3_train_score                                                      0.970297
# split4_train_score                                                      0.970297
# split5_train_score                                                      0.970297
# split6_train_score                                                      0.990099
# split7_train_score                                                      0.970297
# split8_train_score                                                      0.970297
# split9_train_score                                                      0.970297
# mean_train_score                                                        0.972218
# std_train_score                                                       0.00745252
#
#                                                                             643   \
# mean_fit_time                                                        0.000819063
# std_fit_time                                                         0.000211102
# mean_score_time                                                       0.00111811
# std_score_time                                                         0.0004635
# param_classifier               KNeighborsClassifier(algorithm='auto', leaf_si...
# param_classifier__algorithm                                                 auto
# param_classifier__n_neighbors                                                 10
# param_classifier__p                                                            2
# param_classifier__weights                                                uniform
# param_preprocessing                             Normalizer(copy=True, norm='l2')
# params                         {'classifier': KNeighborsClassifier(algorithm=...
# split0_test_score                                                       0.916667
# split1_test_score                                                              1
# split2_test_score                                                              1
# split3_test_score                                                              1
# split4_test_score                                                              1
# split5_test_score                                                              1
# split6_test_score                                                       0.818182
# split7_test_score                                                              1
# split8_test_score                                                              1
# split9_test_score                                                              1
# mean_test_score                                                         0.973214
# std_test_score                                                          0.057213
# rank_test_score                                                                1
# split0_train_score                                                          0.98
# split1_train_score                                                          0.97
# split2_train_score                                                      0.970297
# split3_train_score                                                      0.980198
# split4_train_score                                                      0.970297
# split5_train_score                                                      0.970297
# split6_train_score                                                      0.990099
# split7_train_score                                                      0.970297
# split8_train_score                                                      0.970297
# split9_train_score                                                      0.970297
# mean_train_score                                                        0.974208
# std_train_score                                                       0.00656836
#
#                                                                             638   \
# mean_fit_time                                                        0.000658512
# std_fit_time                                                         7.94283e-05
# mean_score_time                                                      0.000887322
# std_score_time                                                       8.22767e-05
# param_classifier               KNeighborsClassifier(algorithm='auto', leaf_si...
# param_classifier__algorithm                                                 auto
# param_classifier__n_neighbors                                                 10
# param_classifier__p                                                            1
# param_classifier__weights                                               distance
# param_preprocessing                             Normalizer(copy=True, norm='l2')
# params                         {'classifier': KNeighborsClassifier(algorithm=...
# split0_test_score                                                       0.916667
# split1_test_score                                                              1
# split2_test_score                                                              1
# split3_test_score                                                              1
# split4_test_score                                                              1
# split5_test_score                                                              1
# split6_test_score                                                       0.818182
# split7_test_score                                                              1
# split8_test_score                                                              1
# split9_test_score                                                              1
# mean_test_score                                                         0.973214
# std_test_score                                                          0.057213
# rank_test_score                                                                1
# split0_train_score                                                             1
# split1_train_score                                                             1
# split2_train_score                                                             1
# split3_train_score                                                             1
# split4_train_score                                                             1
# split5_train_score                                                             1
# split6_train_score                                                             1
# split7_train_score                                                             1
# split8_train_score                                                             1
# split9_train_score                                                             1
# mean_train_score                                                               1
# std_train_score                                                                0
#
#                                                                             633   \
# mean_fit_time                                                         0.00111239
# std_fit_time                                                         0.000420195
# mean_score_time                                                       0.00138757
# std_score_time                                                        0.00047178
# param_classifier               KNeighborsClassifier(algorithm='auto', leaf_si...
# param_classifier__algorithm                                                 auto
# param_classifier__n_neighbors                                                 10
# param_classifier__p                                                            1
# param_classifier__weights                                                uniform
# param_preprocessing                             Normalizer(copy=True, norm='l2')
# params                         {'classifier': KNeighborsClassifier(algorithm=...
# split0_test_score                                                       0.916667
# split1_test_score                                                              1
# split2_test_score                                                              1
# split3_test_score                                                              1
# split4_test_score                                                              1
# split5_test_score                                                              1
# split6_test_score                                                       0.818182
# split7_test_score                                                              1
# split8_test_score                                                              1
# split9_test_score                                                              1
# mean_test_score                                                         0.973214
# std_test_score                                                          0.057213
# rank_test_score                                                                1
# split0_train_score                                                          0.98
# split1_train_score                                                          0.97
# split2_train_score                                                      0.970297
# split3_train_score                                                      0.980198
# split4_train_score                                                      0.970297
# split5_train_score                                                      0.970297
# split6_train_score                                                      0.990099
# split7_train_score                                                      0.970297
# split8_train_score                                                      0.970297
# split9_train_score                                                      0.970297
# mean_train_score                                                        0.974208
# std_train_score                                                       0.00656836
#
#                                                                             629   \
# mean_fit_time                                                        0.000717163
# std_fit_time                                                          0.00027656
# mean_score_time                                                       0.00131781
# std_score_time                                                       0.000347995
# param_classifier               KNeighborsClassifier(algorithm='auto', leaf_si...
# param_classifier__algorithm                                                 auto
# param_classifier__n_neighbors                                                  9
# param_classifier__p                                                           10
# param_classifier__weights                                               distance
# param_preprocessing                                                         None
# params                         {'classifier': KNeighborsClassifier(algorithm=...
# split0_test_score                                                       0.916667
# split1_test_score                                                              1
# split2_test_score                                                       0.909091
# split3_test_score                                                              1
# split4_test_score                                                              1
# split5_test_score                                                              1
# split6_test_score                                                       0.909091
# split7_test_score                                                              1
# split8_test_score                                                              1
# split9_test_score                                                              1
# mean_test_score                                                         0.973214
# std_test_score                                                         0.0406196
# rank_test_score                                                                1
# split0_train_score                                                             1
# split1_train_score                                                             1
# split2_train_score                                                             1
# split3_train_score                                                             1
# split4_train_score                                                             1
# split5_train_score                                                             1
# split6_train_score                                                             1
# split7_train_score                                                             1
# split8_train_score                                                             1
# split9_train_score                                                             1
# mean_train_score                                                               1
# std_train_score                                                                0
#
#                                                      ...                          \
# mean_fit_time                                        ...
# std_fit_time                                         ...
# mean_score_time                                      ...
# std_score_time                                       ...
# param_classifier                                     ...
# param_classifier__algorithm                          ...
# param_classifier__n_neighbors                        ...
# param_classifier__p                                  ...
# param_classifier__weights                            ...
# param_preprocessing                                  ...
# params                                               ...
# split0_test_score                                    ...
# split1_test_score                                    ...
# split2_test_score                                    ...
# split3_test_score                                    ...
# split4_test_score                                    ...
# split5_test_score                                    ...
# split6_test_score                                    ...
# split7_test_score                                    ...
# split8_test_score                                    ...
# split9_test_score                                    ...
# mean_test_score                                      ...
# std_test_score                                       ...
# rank_test_score                                      ...
# split0_train_score                                   ...
# split1_train_score                                   ...
# split2_train_score                                   ...
# split3_train_score                                   ...
# split4_train_score                                   ...
# split5_train_score                                   ...
# split6_train_score                                   ...
# split7_train_score                                   ...
# split8_train_score                                   ...
# split9_train_score                                   ...
# mean_train_score                                     ...
# std_train_score                                      ...
#
#                                                                             1322  \
# mean_fit_time                                                         0.00379772
# std_fit_time                                                          0.00112226
# mean_score_time                                                       0.00240889
# std_score_time                                                        0.00080828
# param_classifier               KNeighborsClassifier(algorithm='auto', leaf_si...
# param_classifier__algorithm                                            ball_tree
# param_classifier__n_neighbors                                                  9
# param_classifier__p                                                           10
# param_classifier__weights                                                uniform
# param_preprocessing            RobustScaler(copy=True, quantile_range=(25.0, ...
# params                         {'classifier': KNeighborsClassifier(algorithm=...
# split0_test_score                                                       0.833333
# split1_test_score                                                       0.833333
# split2_test_score                                                       0.909091
# split3_test_score                                                       0.727273
# split4_test_score                                                       0.636364
# split5_test_score                                                       0.909091
# split6_test_score                                                       0.727273
# split7_test_score                                                              1
# split8_test_score                                                       0.909091
# split9_test_score                                                              1
# mean_test_score                                                         0.848214
# std_test_score                                                           0.11378
# rank_test_score                                                             2785
# split0_train_score                                                          0.89
# split1_train_score                                                          0.89
# split2_train_score                                                       0.90099
# split3_train_score                                                       0.90099
# split4_train_score                                                      0.891089
# split5_train_score                                                      0.861386
# split6_train_score                                                      0.891089
# split7_train_score                                                      0.881188
# split8_train_score                                                      0.871287
# split9_train_score                                                      0.851485
# mean_train_score                                                         0.88295
# std_train_score                                                        0.0157383
#
#                                                                             602   \
# mean_fit_time                                                         0.00287247
# std_fit_time                                                          0.00102588
# mean_score_time                                                       0.00168536
# std_score_time                                                       0.000424937
# param_classifier               KNeighborsClassifier(algorithm='auto', leaf_si...
# param_classifier__algorithm                                                 auto
# param_classifier__n_neighbors                                                  9
# param_classifier__p                                                            6
# param_classifier__weights                                                uniform
# param_preprocessing            RobustScaler(copy=True, quantile_range=(25.0, ...
# params                         {'classifier': KNeighborsClassifier(algorithm=...
# split0_test_score                                                       0.833333
# split1_test_score                                                       0.833333
# split2_test_score                                                       0.909091
# split3_test_score                                                       0.727273
# split4_test_score                                                       0.636364
# split5_test_score                                                       0.909091
# split6_test_score                                                       0.727273
# split7_test_score                                                              1
# split8_test_score                                                       0.909091
# split9_test_score                                                              1
# mean_test_score                                                         0.848214
# std_test_score                                                           0.11378
# rank_test_score                                                             2785
# split0_train_score                                                           0.9
# split1_train_score                                                          0.89
# split2_train_score                                                       0.90099
# split3_train_score                                                       0.90099
# split4_train_score                                                      0.891089
# split5_train_score                                                      0.851485
# split6_train_score                                                      0.891089
# split7_train_score                                                      0.881188
# split8_train_score                                                      0.871287
# split9_train_score                                                      0.861386
# mean_train_score                                                         0.88395
# std_train_score                                                        0.0164558
#
#                                                                             612   \
# mean_fit_time                                                         0.00166745
# std_fit_time                                                         9.66769e-05
# mean_score_time                                                       0.00100532
# std_score_time                                                       6.43951e-05
# param_classifier               KNeighborsClassifier(algorithm='auto', leaf_si...
# param_classifier__algorithm                                                 auto
# param_classifier__n_neighbors                                                  9
# param_classifier__p                                                            8
# param_classifier__weights                                                uniform
# param_preprocessing            RobustScaler(copy=True, quantile_range=(25.0, ...
# params                         {'classifier': KNeighborsClassifier(algorithm=...
# split0_test_score                                                       0.833333
# split1_test_score                                                       0.833333
# split2_test_score                                                       0.909091
# split3_test_score                                                       0.727273
# split4_test_score                                                       0.636364
# split5_test_score                                                       0.909091
# split6_test_score                                                       0.727273
# split7_test_score                                                              1
# split8_test_score                                                       0.909091
# split9_test_score                                                              1
# mean_test_score                                                         0.848214
# std_test_score                                                           0.11378
# rank_test_score                                                             2785
# split0_train_score                                                           0.9
# split1_train_score                                                          0.89
# split2_train_score                                                       0.90099
# split3_train_score                                                       0.90099
# split4_train_score                                                      0.891089
# split5_train_score                                                      0.861386
# split6_train_score                                                      0.891089
# split7_train_score                                                      0.881188
# split8_train_score                                                      0.871287
# split9_train_score                                                      0.851485
# mean_train_score                                                         0.88395
# std_train_score                                                        0.0164558
#
#                                                                             2722  \
# mean_fit_time                                                         0.00160739
# std_fit_time                                                         0.000132321
# mean_score_time                                                       0.00109537
# std_score_time                                                       9.39435e-05
# param_classifier               KNeighborsClassifier(algorithm='auto', leaf_si...
# param_classifier__algorithm                                                brute
# param_classifier__n_neighbors                                                  9
# param_classifier__p                                                           10
# param_classifier__weights                                                uniform
# param_preprocessing            RobustScaler(copy=True, quantile_range=(25.0, ...
# params                         {'classifier': KNeighborsClassifier(algorithm=...
# split0_test_score                                                       0.833333
# split1_test_score                                                       0.833333
# split2_test_score                                                       0.909091
# split3_test_score                                                       0.727273
# split4_test_score                                                       0.636364
# split5_test_score                                                       0.909091
# split6_test_score                                                       0.727273
# split7_test_score                                                              1
# split8_test_score                                                       0.909091
# split9_test_score                                                              1
# mean_test_score                                                         0.848214
# std_test_score                                                           0.11378
# rank_test_score                                                             2785
# split0_train_score                                                          0.89
# split1_train_score                                                          0.89
# split2_train_score                                                       0.90099
# split3_train_score                                                       0.90099
# split4_train_score                                                      0.891089
# split5_train_score                                                      0.861386
# split6_train_score                                                      0.891089
# split7_train_score                                                      0.881188
# split8_train_score                                                      0.871287
# split9_train_score                                                      0.851485
# mean_train_score                                                         0.88295
# std_train_score                                                        0.0157383
#
#                                                                             622   \
# mean_fit_time                                                         0.00190778
# std_fit_time                                                         0.000117261
# mean_score_time                                                       0.00108128
# std_score_time                                                       5.56631e-05
# param_classifier               KNeighborsClassifier(algorithm='auto', leaf_si...
# param_classifier__algorithm                                                 auto
# param_classifier__n_neighbors                                                  9
# ...
# split7_train_score                                                      0.881188
# split8_train_score                                                      0.871287
# split9_train_score                                                      0.851485
# mean_train_score                                                         0.88295
# std_train_score                                                        0.0157383
#
#                                                                             2712  \
# mean_fit_time                                                         0.00255857
# std_fit_time                                                           0.0011594
# mean_score_time                                                       0.00167227
# std_score_time                                                       0.000551748
# param_classifier               KNeighborsClassifier(algorithm='auto', leaf_si...
# param_classifier__algorithm                                                brute
# param_classifier__n_neighbors                                                  9
# param_classifier__p                                                            8
# param_classifier__weights                                                uniform
# param_preprocessing            RobustScaler(copy=True, quantile_range=(25.0, ...
# params                         {'classifier': KNeighborsClassifier(algorithm=...
# split0_test_score                                                       0.833333
# split1_test_score                                                       0.833333
# split2_test_score                                                       0.909091
# split3_test_score                                                       0.727273
# split4_test_score                                                       0.636364
# split5_test_score                                                       0.909091
# split6_test_score                                                       0.727273
# split7_test_score                                                              1
# split8_test_score                                                       0.909091
# split9_test_score                                                              1
# mean_test_score                                                         0.848214
# std_test_score                                                           0.11378
# rank_test_score                                                             2785
# split0_train_score                                                           0.9
# split1_train_score                                                          0.89
# split2_train_score                                                       0.90099
# split3_train_score                                                       0.90099
# split4_train_score                                                      0.891089
# split5_train_score                                                      0.861386
# split6_train_score                                                      0.891089
# split7_train_score                                                      0.881188
# split8_train_score                                                      0.871287
# split9_train_score                                                      0.851485
# mean_train_score                                                         0.88395
# std_train_score                                                        0.0164558
#
#                                                                             2092  \
# mean_fit_time                                                         0.00352838
# std_fit_time                                                          0.00104545
# mean_score_time                                                       0.00247493
# std_score_time                                                       0.000797496
# param_classifier               KNeighborsClassifier(algorithm='auto', leaf_si...
# param_classifier__algorithm                                              kd_tree
# param_classifier__n_neighbors                                                 10
# param_classifier__p                                                           10
# param_classifier__weights                                                uniform
# param_preprocessing            RobustScaler(copy=True, quantile_range=(25.0, ...
# params                         {'classifier': KNeighborsClassifier(algorithm=...
# split0_test_score                                                       0.833333
# split1_test_score                                                       0.833333
# split2_test_score                                                       0.909091
# split3_test_score                                                       0.727273
# split4_test_score                                                       0.727273
# split5_test_score                                                       0.909091
# split6_test_score                                                       0.727273
# split7_test_score                                                              1
# split8_test_score                                                       0.818182
# split9_test_score                                                              1
# mean_test_score                                                         0.848214
# std_test_score                                                         0.0984845
# rank_test_score                                                             2785
# split0_train_score                                                          0.88
# split1_train_score                                                          0.88
# split2_train_score                                                      0.871287
# split3_train_score                                                      0.881188
# split4_train_score                                                      0.881188
# split5_train_score                                                      0.871287
# split6_train_score                                                      0.881188
# split7_train_score                                                      0.871287
# split8_train_score                                                      0.891089
# split9_train_score                                                      0.841584
# mean_train_score                                                         0.87501
# std_train_score                                                        0.0125766
#
#                                                                             1392  \
# mean_fit_time                                                         0.00298388
# std_fit_time                                                          0.00124374
# mean_score_time                                                       0.00188441
# std_score_time                                                       0.000806676
# param_classifier               KNeighborsClassifier(algorithm='auto', leaf_si...
# param_classifier__algorithm                                            ball_tree
# param_classifier__n_neighbors                                                 10
# param_classifier__p                                                           10
# param_classifier__weights                                                uniform
# param_preprocessing            RobustScaler(copy=True, quantile_range=(25.0, ...
# params                         {'classifier': KNeighborsClassifier(algorithm=...
# split0_test_score                                                       0.833333
# split1_test_score                                                       0.833333
# split2_test_score                                                       0.909091
# split3_test_score                                                       0.727273
# split4_test_score                                                       0.727273
# split5_test_score                                                       0.909091
# split6_test_score                                                       0.727273
# split7_test_score                                                              1
# split8_test_score                                                       0.818182
# split9_test_score                                                              1
# mean_test_score                                                         0.848214
# std_test_score                                                         0.0984845
# rank_test_score                                                             2785
# split0_train_score                                                          0.88
# split1_train_score                                                          0.88
# split2_train_score                                                      0.871287
# split3_train_score                                                      0.881188
# split4_train_score                                                      0.881188
# split5_train_score                                                      0.871287
# split6_train_score                                                      0.881188
# split7_train_score                                                      0.871287
# split8_train_score                                                      0.891089
# split9_train_score                                                      0.841584
# mean_train_score                                                         0.87501
# std_train_score                                                        0.0125766
#
#                                                                             692   \
# mean_fit_time                                                         0.00171633
# std_fit_time                                                         0.000141703
# mean_score_time                                                       0.00101016
# std_score_time                                                       8.42971e-05
# param_classifier               KNeighborsClassifier(algorithm='auto', leaf_si...
# param_classifier__algorithm                                                 auto
# param_classifier__n_neighbors                                                 10
# param_classifier__p                                                           10
# param_classifier__weights                                                uniform
# param_preprocessing            RobustScaler(copy=True, quantile_range=(25.0, ...
# params                         {'classifier': KNeighborsClassifier(algorithm=...
# split0_test_score                                                       0.833333
# split1_test_score                                                       0.833333
# split2_test_score                                                       0.909091
# split3_test_score                                                       0.727273
# split4_test_score                                                       0.727273
# split5_test_score                                                       0.909091
# split6_test_score                                                       0.727273
# split7_test_score                                                              1
# split8_test_score                                                       0.818182
# split9_test_score                                                              1
# mean_test_score                                                         0.848214
# std_test_score                                                         0.0984845
# rank_test_score                                                             2785
# split0_train_score                                                          0.88
# split1_train_score                                                          0.88
# split2_train_score                                                      0.871287
# split3_train_score                                                      0.881188
# split4_train_score                                                      0.881188
# split5_train_score                                                      0.871287
# split6_train_score                                                      0.881188
# split7_train_score                                                      0.871287
# split8_train_score                                                      0.891089
# split9_train_score                                                      0.841584
# mean_train_score                                                         0.87501
# std_train_score                                                        0.0125766
#
#                                                                             2002
# mean_fit_time                                                         0.00190158
# std_fit_time                                                         0.000107858
# mean_score_time                                                       0.00114162
# std_score_time                                                        0.00011189
# param_classifier               KNeighborsClassifier(algorithm='auto', leaf_si...
# param_classifier__algorithm                                              kd_tree
# param_classifier__n_neighbors                                                  9
# param_classifier__p                                                            6
# param_classifier__weights                                                uniform
# param_preprocessing            RobustScaler(copy=True, quantile_range=(25.0, ...
# params                         {'classifier': KNeighborsClassifier(algorithm=...
# split0_test_score                                                       0.833333
# split1_test_score                                                       0.833333
# split2_test_score                                                       0.909091
# split3_test_score                                                       0.727273
# split4_test_score                                                       0.636364
# split5_test_score                                                       0.909091
# split6_test_score                                                       0.727273
# split7_test_score                                                              1
# split8_test_score                                                       0.909091
# split9_test_score                                                              1
# mean_test_score                                                         0.848214
# std_test_score                                                           0.11378
# rank_test_score                                                             2785
# split0_train_score                                                           0.9
# split1_train_score                                                          0.89
# split2_train_score                                                       0.90099
# split3_train_score                                                       0.90099
# split4_train_score                                                      0.891089
# split5_train_score                                                      0.851485
# split6_train_score                                                      0.891089
# split7_train_score                                                      0.881188
# split8_train_score                                                      0.871287
# split9_train_score                                                      0.861386
# mean_train_score                                                         0.88395
# std_train_score                                                        0.0164558
#
# [36 rows x 2800 columns]
