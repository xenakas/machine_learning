# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, KFold 
from sklearn.neighbors import KNeighborsRegressor 
from sklearn.datasets import load_boston
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.pipeline import Pipeline

# %%
boston=load_boston()
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
print(boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# https://archive.ics.uci.edu/ml/machine-learning-databases/housing/
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# .. topic:: References
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.

# %%
df=pd.DataFrame(boston.data,columns=boston.feature_names)
df.head(5)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
df_target=pd.DataFrame(boston.target,columns=["MEDV"])
df_target.head()
# Out:
#    MEDV
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %%
df_full=pd.concat([df,df_target],axis=1)
df_full.head(5)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# ## Шаг 1. Строим самую простую модель

# %%
X_train, X_test, y_train, y_test = train_test_split(boston.data, boston.target, random_state=1)

knn = KNeighborsRegressor(n_neighbors=4)
knn.fit(X_train, y_train)

sc_train = knn.score(X_train , y_train)
sc_test = knn.score(X_test , y_test)


print("тренировочный: {:.3f}".format(sc_train))
print("тестовый: {:.3f}".format(sc_test))
# Out:
# тренировочный: 0.716
# тестовый: 0.585

# %% [markdown]
# ## Шаг 2. Проводим препроцессинг (пересмасштабирование) данных

# %%
X_train, X_test, y_train, y_test = train_test_split(boston.data, boston.target, random_state=1)

scaler = MinMaxScaler() 
# находим функцию масштабирования
scaler.fit(X_train) # Перемасштабирование ТОЛЬКО на ТРЕНИРОВОЦНОМ наборе,  


X_train_scaled = scaler.transform(X_train) # перемасштабировали тренировочный набор
X_test_scaled = scaler.transform(X_test)   # перемасштабировали тестовый набор


knn = KNeighborsRegressor(n_neighbors=4)
knn.fit(X_train_scaled, y_train)

sc_train = knn.score(X_train_scaled , y_train)
sc_test =  knn.score(X_test_scaled ,  y_test)

print("тренировочный: {:.3f}".format(sc_train))
print("тестовый: {:.3f}".format(sc_test))
# Out:
# тренировочный: 0.841
# тестовый: 0.781

# %% [markdown]
# ## Шаг 2.5 Посмотрим метрики результатов
# https://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics

# %%
X_train, X_test, y_train, y_test = train_test_split(boston.data, boston.target, random_state=1)

scaler = MinMaxScaler() 
# находим функцию масштабирования
scaler.fit(X_train) # Перемасштабирование ТОЛЬКО на ТРЕНИРОВОЦНОМ наборе,  

X_train_scaled = scaler.transform(X_train) # перемасштабировали тренировочный набор
X_test_scaled = scaler.transform(X_test)   # перемасштабировали тестовый набор

knn = KNeighborsRegressor(n_neighbors=4)
knn.fit(X_train_scaled, y_train)

# предскажем значение тренировочный и тестовых y
y_pred_train=knn.predict(X_train_scaled)
y_pred=knn.predict(X_test_scaled)

# Проверим тренировочный набор (не всегда нужно делать)
print('тренировочный R^2: {:.3f}'.format( r2_score(y_train,y_pred_train) ) )
# MSE само по себе мало значит, но важно при сравнении дрс другими результатами 
print('тренировочный MSE: {:.3f}'.format( mean_squared_error(y_train,y_pred_train) ) ) 

# Проверим тренировочный набор (не всегда нужно делать)
print('тестовый R^2: {:.3f}'.format( r2_score(y_test,y_pred) ) )
# MSE само по себе мало значит, но важно при сравнении дрс другими результатами 
print('тестовый MSE: {:.3f}'.format( mean_squared_error(y_test,y_pred) ) )
# Out:
# тренировочный R^2: 0.841
# тренировочный MSE: 12.637
# тестовый R^2: 0.781
# тестовый MSE: 21.691

# %% [markdown]
# ## Шаг 3. Добавим поиск оптимального параметра

# %%
X_train, X_test, y_train, y_test = train_test_split(boston.data, boston.target, random_state=1) # 1, 12, 100

scaler = MinMaxScaler() 
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train) 
X_test_scaled = scaler.transform(X_test) 

sc_train=[]
sc_test=[]
sc_train_mse=[]
sc_test_mse=[]

ran=range(1,10)

for r in ran:
    knn = KNeighborsRegressor(n_neighbors=r)
    knn.fit(X_train_scaled, y_train)
    sc_train=np.append(sc_train,knn.score(X_train_scaled ,y_train))
    sc_test=np.append(sc_test, knn.score(X_test_scaled ,y_test)) 
    y_pred=knn.predict(X_test_scaled)
    sc_test_mse=np.append(sc_test_mse,  mean_squared_error (y_test, y_pred)   )
    
np.set_printoptions(precision=3)
print(sc_train)
print(sc_test)
print(sc_test_mse)

fig, ax1 = plt.subplots()
ax1.plot(ran,sc_train,ran,sc_test)
ax1.set_xlabel('кол. соседей')
ax1.set_ylabel('R^2')
ax2 = ax1.twinx()
ax2.plot(ran,sc_test_mse,'-g')
ax2.set_ylabel('СКО') #  СКО - среднеквадрат ошибка  или MSE - mean squared error
plt.show()
# Out:
# [1.    0.908 0.873 0.841 0.8   0.761 0.734 0.723 0.708]
# [0.755 0.801 0.806 0.781 0.771 0.748 0.729 0.718 0.706]
# [24.263 19.752 19.195 21.691 22.728 25.009 26.812 27.906 29.131]

# %% [markdown]
# ## Итоговый шаг. Строим коннтейнеры

# %%
X_train, X_test, y_train, y_test = train_test_split(boston.data, boston.target, random_state=12, test_size=0.2)

kfold = KFold(n_splits=10, shuffle=True, random_state=1)

pipe = Pipeline([('preprocessing', MinMaxScaler()), 
                 ('classifier', KNeighborsRegressor())])

n_neighbors=[1, 2, 3, 4, 5]
p=[1, 2, 3, 4, 6, 8, 10]
weights=['uniform','distance']

param_grid =[
    {'preprocessing': [MinMaxScaler(), StandardScaler(),RobustScaler()], 
     'classifier': [KNeighborsRegressor()],
     'classifier__n_neighbors': n_neighbors,
     'classifier__p': p,
     'classifier__weights': weights
     }
]

grid = GridSearchCV(pipe, param_grid, cv=kfold, return_train_score=True, iid=True)
grid.fit(X_train,y_train)

print("----------------- Обучили и тестировали -------------------")
print("Наилучшие параметры:\n{}\n".format(grid.best_params_))
print("Средняя правильность для наилучшей модели кроссвалидации на валидационных тестовых наборах: {:.6f}\n".format(grid.best_score_)) 
print("Правильность для наилучшей модели на тестовом наборе: {:.6f}\n".format(grid.score(X_test, y_test)))
gridresults = pd.DataFrame(grid.cv_results_)
display(gridresults.sort_values(["rank_test_score"]).T)
# Out:
# ----------------- Обучили и тестировали -------------------
# Наилучшие параметры:
# {'classifier': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=None, n_neighbors=4, p=1,
#           weights='distance'), 'classifier__n_neighbors': 4, 'classifier__p': 1, 'classifier__weights': 'distance', 'preprocessing': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#        with_scaling=True)}
#
# Средняя правильность для наилучшей модели кроссвалидации на валидационных тестовых наборах: 0.784266
#
# Правильность для наилучшей модели на тестовом наборе: 0.848867
#                                                                              131  \
# mean_fit_time                                                         0.00196815
# std_fit_time                                                         5.83304e-05
# mean_score_time                                                      0.000679135
# std_score_time                                                       2.30434e-05
# param_classifier               KNeighborsRegressor(algorithm='auto', leaf_siz...
# param_classifier__n_neighbors                                                  4
# param_classifier__p                                                            1
# param_classifier__weights                                               distance
# param_preprocessing            RobustScaler(copy=True, quantile_range=(25.0, ...
# params                         {'classifier': KNeighborsRegressor(algorithm='...
# split0_test_score                                                       0.707961
# split1_test_score                                                       0.691508
# split2_test_score                                                       0.738795
# split3_test_score                                                       0.868012
# split4_test_score                                                        0.87633
# split5_test_score                                                       0.685483
# split6_test_score                                                       0.828674
# split7_test_score                                                       0.791723
# split8_test_score                                                       0.893982
# split9_test_score                                                       0.763464
# mean_test_score                                                         0.784266
# std_test_score                                                         0.0750097
# rank_test_score                                                                1
# split0_train_score                                                             1
# split1_train_score                                                             1
# split2_train_score                                                             1
# split3_train_score                                                             1
# split4_train_score                                                             1
# split5_train_score                                                             1
# split6_train_score                                                             1
# split7_train_score                                                             1
# split8_train_score                                                             1
# split9_train_score                                                             1
# mean_train_score                                                               1
# std_train_score                                                                0
#
#                                                                              173  \
# mean_fit_time                                                         0.00208158
# std_fit_time                                                         0.000167312
# mean_score_time                                                        0.0007617
# std_score_time                                                       0.000138276
# param_classifier               KNeighborsRegressor(algorithm='auto', leaf_siz...
# param_classifier__n_neighbors                                                  5
# param_classifier__p                                                            1
# param_classifier__weights                                               distance
# param_preprocessing            RobustScaler(copy=True, quantile_range=(25.0, ...
# params                         {'classifier': KNeighborsRegressor(algorithm='...
# split0_test_score                                                       0.698803
# split1_test_score                                                       0.702907
# split2_test_score                                                       0.729261
# split3_test_score                                                       0.867397
# split4_test_score                                                          0.901
# split5_test_score                                                       0.675869
# split6_test_score                                                       0.791934
# split7_test_score                                                       0.757133
# split8_test_score                                                        0.88512
# split9_test_score                                                       0.781788
# mean_test_score                                                         0.778829
# std_test_score                                                         0.0774002
# rank_test_score                                                                2
# split0_train_score                                                             1
# split1_train_score                                                             1
# split2_train_score                                                             1
# split3_train_score                                                             1
# split4_train_score                                                             1
# split5_train_score                                                             1
# split6_train_score                                                             1
# split7_train_score                                                             1
# split8_train_score                                                             1
# split9_train_score                                                             1
# mean_train_score                                                               1
# std_train_score                                                                0
#
#                                                                              88   \
# mean_fit_time                                                        0.000740266
# std_fit_time                                                          0.00018912
# mean_score_time                                                      0.000841022
# std_score_time                                                         0.0002719
# param_classifier               KNeighborsRegressor(algorithm='auto', leaf_siz...
# param_classifier__n_neighbors                                                  3
# param_classifier__p                                                            1
# param_classifier__weights                                               distance
# param_preprocessing            StandardScaler(copy=True, with_mean=True, with...
# params                         {'classifier': KNeighborsRegressor(algorithm='...
# split0_test_score                                                        0.64813
# split1_test_score                                                       0.722274
# split2_test_score                                                       0.768316
# split3_test_score                                                       0.846542
# split4_test_score                                                       0.906994
# split5_test_score                                                       0.685926
# split6_test_score                                                       0.799401
# split7_test_score                                                       0.780725
# split8_test_score                                                       0.916392
# split9_test_score                                                       0.681811
# mean_test_score                                                         0.775361
# std_test_score                                                         0.0886082
# rank_test_score                                                                3
# split0_train_score                                                             1
# split1_train_score                                                             1
# split2_train_score                                                             1
# split3_train_score                                                             1
# split4_train_score                                                             1
# split5_train_score                                                             1
# split6_train_score                                                             1
# split7_train_score                                                             1
# split8_train_score                                                             1
# split9_train_score                                                             1
# mean_train_score                                                               1
# std_train_score                                                                0
#
#                                                                              130  \
# mean_fit_time                                                        0.000588655
# std_fit_time                                                         2.75783e-06
# mean_score_time                                                      0.000698972
# std_score_time                                                       2.15826e-05
# param_classifier               KNeighborsRegressor(algorithm='auto', leaf_siz...
# param_classifier__n_neighbors                                                  4
# param_classifier__p                                                            1
# param_classifier__weights                                               distance
# param_preprocessing            StandardScaler(copy=True, with_mean=True, with...
# params                         {'classifier': KNeighborsRegressor(algorithm='...
# split0_test_score                                                       0.603117
# split1_test_score                                                       0.703371
# split2_test_score                                                       0.730753
# split3_test_score                                                       0.855281
# split4_test_score                                                       0.905676
# split5_test_score                                                       0.790295
# split6_test_score                                                       0.809119
# split7_test_score                                                        0.71365
# split8_test_score                                                        0.91309
# split9_test_score                                                       0.723246
# mean_test_score                                                         0.774249
# std_test_score                                                         0.0934139
# rank_test_score                                                                4
# split0_train_score                                                             1
# split1_train_score                                                             1
# split2_train_score                                                             1
# split3_train_score                                                             1
# split4_train_score                                                             1
# split5_train_score                                                             1
# split6_train_score                                                             1
# split7_train_score                                                             1
# split8_train_score                                                             1
# split9_train_score                                                             1
# mean_train_score                                                               1
# std_train_score                                                                0
#
#                                                                              172  \
# mean_fit_time                                                        0.000590062
# std_fit_time                                                         3.26459e-06
# mean_score_time                                                      0.000699353
# std_score_time                                                       8.57846e-06
# param_classifier               KNeighborsRegressor(algorithm='auto', leaf_siz...
# param_classifier__n_neighbors                                                  5
# param_classifier__p                                                            1
# param_classifier__weights                                               distance
# param_preprocessing            StandardScaler(copy=True, with_mean=True, with...
# params                         {'classifier': KNeighborsRegressor(algorithm='...
# split0_test_score                                                       0.619984
# split1_test_score                                                       0.676802
# split2_test_score                                                        0.70556
# split3_test_score                                                       0.841544
# split4_test_score                                                       0.912511
# split5_test_score                                                       0.807665
# split6_test_score                                                       0.817187
# split7_test_score                                                        0.68785
# split8_test_score                                                       0.904314
# split9_test_score                                                       0.735593
# mean_test_score                                                         0.770308
# std_test_score                                                         0.0951286
# rank_test_score                                                                5
# split0_train_score                                                             1
# split1_train_score                                                             1
# split2_train_score                                                             1
# split3_train_score                                                             1
# split4_train_score                                                             1
# split5_train_score                                                             1
# split6_train_score                                                             1
# split7_train_score                                                             1
# split8_train_score                                                             1
# split9_train_score                                                             1
# mean_train_score                                                               1
# std_train_score                                                                0
#
#                                                                              128  \
# mean_fit_time                                                         0.00201912
# std_fit_time                                                         3.98949e-05
# mean_score_time                                                      0.000662184
# std_score_time                                                       1.74311e-05
# param_classifier               KNeighborsRegressor(algorithm='auto', leaf_siz...
# param_classifier__n_neighbors                                                  4
# param_classifier__p                                                            1
# param_classifier__weights                                                uniform
# param_preprocessing            RobustScaler(copy=True, quantile_range=(25.0, ...
# params                         {'classifier': KNeighborsRegressor(algorithm='...
# split0_test_score                                                       0.695927
# split1_test_score                                                       0.695504
# split2_test_score                                                       0.722844
# split3_test_score                                                       0.834903
# split4_test_score                                                       0.865256
# split5_test_score                                                       0.610421
# split6_test_score                                                       0.830988
# split7_test_score                                                       0.784948
# split8_test_score                                                       0.868688
# split9_test_score                                                       0.774883
# mean_test_score                                                         0.768128
# std_test_score                                                         0.0809102
# rank_test_score                                                                6
# split0_train_score                                                      0.878703
# split1_train_score                                                      0.861926
# split2_train_score                                                      0.861165
# split3_train_score                                                      0.837701
# split4_train_score                                                       0.88421
# split5_train_score                                                      0.872021
# split6_train_score                                                      0.869241
# split7_train_score                                                      0.883335
# split8_train_score                                                       0.86602
# split9_train_score                                                      0.872852
# mean_train_score                                                        0.868717
# std_train_score                                                        0.0128614
#
#                                                                              94   \
# mean_fit_time                                                        0.000609732
# std_fit_time                                                         3.67845e-06
# mean_score_time                                                      0.000665331
# std_score_time                                                       6.67248e-06
# param_classifier               KNeighborsRegressor(algorithm='auto', leaf_siz...
# param_classifier__n_neighbors                                                  3
# param_classifier__p                                                            2
# param_classifier__weights                                               distance
# param_preprocessing            StandardScaler(copy=True, with_mean=True, with...
# params                         {'classifier': KNeighborsRegressor(algorithm='...
# split0_test_score                                                       0.593817
# split1_test_score                                                       0.679686
# split2_test_score                                                       0.726262
# split3_test_score                                                       0.844048
# split4_test_score                                                       0.882491
# split5_test_score                                                       0.680818
# split6_test_score                                                       0.825354
# split7_test_score                                                       0.777351
# split8_test_score                                                       0.864779
# split9_test_score                                                       0.797497
# mean_test_score                                                         0.766653
# std_test_score                                                         0.0896141
# rank_test_score                                                                7
# split0_train_score                                                             1
# split1_train_score                                                             1
# split2_train_score                                                             1
# split3_train_score                                                             1
# split4_train_score                                                             1
# split5_train_score                                                             1
# split6_train_score                                                             1
# split7_train_score                                                             1
# split8_train_score                                                             1
# split9_train_score                                                             1
# mean_train_score                                                               1
# std_train_score                                                                0
#
#                                                                              184  \
# mean_fit_time                                                        0.000688863
# std_fit_time                                                         0.000150266
# mean_score_time                                                       0.00481269
# std_score_time                                                       0.000421266
# param_classifier               KNeighborsRegressor(algorithm='auto', leaf_siz...
# param_classifier__n_neighbors                                                  5
# param_classifier__p                                                            3
# param_classifier__weights                                               distance
# param_preprocessing            StandardScaler(copy=True, with_mean=True, with...
# params                         {'classifier': KNeighborsRegressor(algorithm='...
# split0_test_score                                                       0.599554
# split1_test_score                                                        0.74877
# split2_test_score                                                       0.709671
# split3_test_score                                                       0.822536
# split4_test_score                                                       0.850752
# split5_test_score                                                       0.661076
# split6_test_score                                                       0.836931
# split7_test_score                                                       0.713312
# split8_test_score                                                       0.836487
# split9_test_score                                                        0.81755
# mean_test_score                                                         0.759272
# std_test_score                                                         0.0822924
# rank_test_score                                                                8
# split0_train_score                                                             1
# split1_train_score                                                             1
# split2_train_score                                                             1
# split3_train_score                                                             1
# split4_train_score                                                             1
# split5_train_score                                                             1
# split6_train_score                                                             1
# split7_train_score                                                             1
# split8_train_score                                                             1
# split9_train_score                                                             1
# mean_train_score                                                               1
# std_train_score                                                                0
#
#                                                                              85   \
# mean_fit_time                                                         0.00058279
# std_fit_time                                                         9.18651e-06
# mean_score_time                                                      0.000626063
# std_score_time                                                       9.12956e-06
# param_classifier               KNeighborsRegressor(algorithm='auto', leaf_siz...
# param_classifier__n_neighbors                                                  3
# param_classifier__p                                                            1
# param_classifier__weights                                                uniform
# param_preprocessing            StandardScaler(copy=True, with_mean=True, with...
# params                         {'classifier': KNeighborsRegressor(algorithm='...
# split0_test_score                                                       0.652117
# split1_test_score                                                       0.737166
# split2_test_score                                                       0.747766
# split3_test_score                                                       0.786788
# split4_test_score                                                        0.90048
# split5_test_score                                                       0.640463
# split6_test_score                                                        0.79213
# split7_test_score                                                       0.773517
# split8_test_score                                                       0.898895
# split9_test_score                                                       0.656221
# mean_test_score                                                         0.758281
# std_test_score                                                         0.0882302
# rank_test_score                                                                9
# split0_train_score                                                      0.902097
# split1_train_score                                                      0.885584
# split2_train_score                                                      0.879364
# split3_train_score                                                      0.870939
# split4_train_score                                                      0.884403
# split5_train_score                                                      0.897317
# split6_train_score                                                      0.884486
# split7_train_score                                                       0.89091
# split8_train_score                                                      0.891289
# split9_train_score                                                      0.904129
# mean_train_score                                                        0.889052
# std_train_score                                                       0.00975026
#
#                                                                              89   \
# mean_fit_time                                                         0.00204144
# std_fit_time                                                         3.33948e-05
# mean_score_time                                                      0.000690913
# std_score_time                                                       1.35859e-05
# param_classifier               KNeighborsRegressor(algorithm='auto', leaf_siz...
# param_classifier__n_neighbors                                                  3
# param_classifier__p                                                            1
# param_classifier__weights                                               distance
# param_preprocessing            RobustScaler(copy=True, quantile_range=(25.0, ...
# params                         {'classifier': KNeighborsRegressor(algorithm='...
# split0_test_score                                                       0.703209
# split1_test_score                                                       0.686472
# split2_test_score                                                       0.627679
# split3_test_score                                                        0.87075
# split4_test_score                                                       0.839514
# split5_test_score                                                       0.676324
# split6_test_score                                                        0.77281
# split7_test_score                                                        0.76448
# split8_test_score                                                       0.883768
# split9_test_score                                                       0.757852
# mean_test_score                                                         0.757927
# std_test_score                                                          0.082146
# rank_test_score                                                               10
# split0_train_score                                                             1
# split1_train_score                                                             1
# split2_train_score                                                             1
# split3_train_score                                                             1
# split4_train_score                                                             1
# split5_train_score                                                             1
# split6_train_score                                                             1
# split7_train_score                                                             1
# split8_train_score                                                             1
# split9_train_score                                                             1
# mean_train_score                                                               1
# std_train_score                                                                0
#
#                                                      ...                          \
# mean_fit_time                                        ...
# std_fit_time                                         ...
# mean_score_time                                      ...
# std_score_time                                       ...
# param_classifier                                     ...
# param_classifier__n_neighbors                        ...
# param_classifier__p                                  ...
# param_classifier__weights                            ...
# param_preprocessing                                  ...
# params                                               ...
# split0_test_score                                    ...
# split1_test_score                                    ...
# split2_test_score                                    ...
# split3_test_score                                    ...
# split4_test_score                                    ...
# split5_test_score                                    ...
# split6_test_score                                    ...
# split7_test_score                                    ...
# split8_test_score                                    ...
# split9_test_score                                    ...
# mean_test_score                                      ...
# std_test_score                                       ...
# rank_test_score                                      ...
# split0_train_score                                   ...
# split1_train_score                                   ...
# split2_train_score                                   ...
# split3_train_score                                   ...
# split4_train_score                                   ...
# split5_train_score                                   ...
# split6_train_score                                   ...
# split7_train_score                                   ...
# split8_train_score                                   ...
# split9_train_score                                   ...
# mean_train_score                                     ...
# std_train_score                                      ...
#
#                                                                              26   \
# mean_fit_time                                                         0.00201297
# std_fit_time                                                         0.000143765
# mean_score_time                                                       0.00318239
# std_score_time                                                       0.000478778
# param_classifier               KNeighborsRegressor(algorithm='auto', leaf_siz...
# param_classifier__n_neighbors                                                  1
# param_classifier__p                                                            6
# param_classifier__weights                                                uniform
# param_preprocessing            RobustScaler(copy=True, quantile_range=(25.0, ...
# params                         {'classifier': KNeighborsRegressor(algorithm='...
# split0_test_score                                                       0.693852
# split1_test_score                                                         0.6183
# split2_test_score                                                       0.435201
# split3_test_score                                                       0.844713
# split4_test_score                                                       0.723452
# split5_test_score                                                       0.238934
# split6_test_score                                                       0.857531
# split7_test_score                                                       0.626074
# split8_test_score                                                       0.847067
# split9_test_score                                                       0.496299
# mean_test_score                                                          0.63824
# std_test_score                                                          0.190941
# rank_test_score                                                              200
# split0_train_score                                                             1
# split1_train_score                                                             1
# split2_train_score                                                             1
# split3_train_score                                                             1
# split4_train_score                                                             1
# split5_train_score                                                             1
# split6_train_score                                                             1
# split7_train_score                                                             1
# split8_train_score                                                             1
# split9_train_score                                                             1
# mean_train_score                                                               1
# std_train_score                                                                0
#
#                                                                              14   \
# mean_fit_time                                                         0.00225921
# std_fit_time                                                         0.000289913
# mean_score_time                                                       0.00369129
# std_score_time                                                       0.000620138
# param_classifier               KNeighborsRegressor(algorithm='auto', leaf_siz...
# param_classifier__n_neighbors                                                  1
# param_classifier__p                                                            3
# param_classifier__weights                                                uniform
# param_preprocessing            RobustScaler(copy=True, quantile_range=(25.0, ...
# params                         {'classifier': KNeighborsRegressor(algorithm='...
# split0_test_score                                                       0.705033
# split1_test_score                                                       0.612059
# split2_test_score                                                       0.438596
# split3_test_score                                                       0.837792
# split4_test_score                                                       0.686332
# split5_test_score                                                         0.2194
# split6_test_score                                                        0.86086
# split7_test_score                                                       0.651256
# split8_test_score                                                       0.851796
# split9_test_score                                                       0.503973
# mean_test_score                                                         0.636825
# std_test_score                                                          0.193465
# rank_test_score                                                              202
# split0_train_score                                                             1
# split1_train_score                                                             1
# split2_train_score                                                             1
# split3_train_score                                                             1
# split4_train_score                                                             1
# split5_train_score                                                             1
# split6_train_score                                                             1
# split7_train_score                                                             1
# split8_train_score                                                             1
# split9_train_score                                                             1
# mean_train_score                                                               1
# std_train_score                                                                0
#
#                                                                              17   \
# mean_fit_time                                                         0.00219688
# std_fit_time                                                          0.00010394
# mean_score_time                                                       0.00358372
# std_score_time                                                       0.000489541
# param_classifier               KNeighborsRegressor(algorithm='auto', leaf_siz...
# param_classifier__n_neighbors                                                  1
# param_classifier__p                                                            3
# param_classifier__weights                                               distance
# param_preprocessing            RobustScaler(copy=True, quantile_range=(25.0, ...
# params                         {'classifier': KNeighborsRegressor(algorithm='...
# split0_test_score                                                       0.705033
# split1_test_score                                                       0.612059
# split2_test_score                                                       0.438596
# split3_test_score                                                       0.837792
# split4_test_score                                                       0.686332
# split5_test_score                                                         0.2194
# split6_test_score                                                        0.86086
# split7_test_score                                                       0.651256
# split8_test_score                                                       0.851796
# split9_test_score                                                       0.503973
# mean_test_score                                                         0.636825
# std_test_score                                                          0.193465
# rank_test_score                                                              202
# split0_train_score                                                             1
# split1_train_score                                                             1
# split2_train_score                                                             1
# split3_train_score                                                             1
# split4_train_score                                                             1
# split5_train_score                                                             1
# split6_train_score                                                             1
# split7_train_score                                                             1
# split8_train_score                                                             1
# split9_train_score                                                             1
# mean_train_score                                                               1
# std_train_score                                                                0
#
#                                                                              74   \
# mean_fit_time                                                         0.00199494
# std_fit_time                                                         4.24704e-05
# mean_score_time                                                       0.00357344
# std_score_time                                                       0.000534298
# param_classifier               KNeighborsRegressor(algorithm='auto', leaf_siz...
# param_classifier__n_neighbors                                                  2
# param_classifier__p                                                            8
# param_classifier__weights                                                uniform
# param_preprocessing            RobustScaler(copy=True, quantile_range=(25.0, ...
# params                         {'classifier': KNeighborsRegressor(algorithm='...
# split0_test_score                                                       0.677656
# split1_test_score                                                       0.616438
# split2_test_score                                                       0.625119
# split3_test_score                                                       0.851234
# split4_test_score                                                       0.723614
# split5_test_score                                                      0.0942634
# split6_test_score                                                       0.796263
# split7_test_score                                                       0.563484
# split8_test_score                                                        0.79749
# split9_test_score                                                       0.607093
# mean_test_score                                                         0.635833
# std_test_score                                                          0.201182
# rank_test_score                                                              204
# split0_train_score                                                      0.900335
# split1_train_score                                                      0.897188
# split2_train_score                                                      0.897534
# split3_train_score                                                      0.882461
# split4_train_score                                                      0.907719
# split5_train_score                                                      0.918573
# split6_train_score                                                      0.906009
# split7_train_score                                                      0.907818
# split8_train_score                                                       0.90527
# split9_train_score                                                       0.90747
# mean_train_score                                                        0.903038
# std_train_score                                                       0.00902658
#
#                                                                              8    \
# mean_fit_time                                                         0.00280342
# std_fit_time                                                         0.000568398
# mean_score_time                                                      0.000872564
# std_score_time                                                       0.000258723
# param_classifier               KNeighborsRegressor(algorithm='auto', leaf_siz...
# param_classifier__n_neighbors                                                  1
# param_classifier__p                                                            2
# param_classifier__weights                                                uniform
# param_preprocessing            RobustScaler(copy=True, quantile_range=(25.0, ...
# params                         {'classifier': KNeighborsRegressor(algorithm='...
# split0_test_score                                                       0.678163
# split1_test_score                                                       0.609202
# split2_test_score                                                       0.582816
# split3_test_score                                                       0.847567
# split4_test_score                                                       0.680547
# split5_test_score                                                       0.105071
# split6_test_score                                                       0.651745
# split7_test_score                                                       0.652471
# split8_test_score                                                       0.834804
# split9_test_score                                                       0.606627
# mean_test_score                                                         0.625441
# std_test_score                                                          0.192685
# ...
# split2_train_score                                                             1
# split3_train_score                                                             1
# split4_train_score                                                             1
# split5_train_score                                                             1
# split6_train_score                                                             1
# split7_train_score                                                             1
# split8_train_score                                                             1
# split9_train_score                                                             1
# mean_train_score                                                               1
# std_train_score                                                                0
#
#                                                                              11   \
# mean_fit_time                                                         0.00200205
# std_fit_time                                                         3.56545e-05
# mean_score_time                                                      0.000628138
# std_score_time                                                       1.28207e-05
# param_classifier               KNeighborsRegressor(algorithm='auto', leaf_siz...
# param_classifier__n_neighbors                                                  1
# param_classifier__p                                                            2
# param_classifier__weights                                               distance
# param_preprocessing            RobustScaler(copy=True, quantile_range=(25.0, ...
# params                         {'classifier': KNeighborsRegressor(algorithm='...
# split0_test_score                                                       0.678163
# split1_test_score                                                       0.609202
# split2_test_score                                                       0.582816
# split3_test_score                                                       0.847567
# split4_test_score                                                       0.680547
# split5_test_score                                                       0.105071
# split6_test_score                                                       0.651745
# split7_test_score                                                       0.652471
# split8_test_score                                                       0.834804
# split9_test_score                                                       0.606627
# mean_test_score                                                         0.625441
# std_test_score                                                          0.192685
# rank_test_score                                                              205
# split0_train_score                                                             1
# split1_train_score                                                             1
# split2_train_score                                                             1
# split3_train_score                                                             1
# split4_train_score                                                             1
# split5_train_score                                                             1
# split6_train_score                                                             1
# split7_train_score                                                             1
# split8_train_score                                                             1
# split9_train_score                                                             1
# mean_train_score                                                               1
# std_train_score                                                                0
#
#                                                                              32   \
# mean_fit_time                                                         0.00225499
# std_fit_time                                                         0.000291457
# mean_score_time                                                       0.00368574
# std_score_time                                                       0.000897327
# param_classifier               KNeighborsRegressor(algorithm='auto', leaf_siz...
# param_classifier__n_neighbors                                                  1
# param_classifier__p                                                            8
# param_classifier__weights                                                uniform
# param_preprocessing            RobustScaler(copy=True, quantile_range=(25.0, ...
# params                         {'classifier': KNeighborsRegressor(algorithm='...
# split0_test_score                                                       0.693852
# split1_test_score                                                       0.283455
# split2_test_score                                                       0.444838
# split3_test_score                                                       0.840005
# split4_test_score                                                       0.664806
# split5_test_score                                                       0.238934
# split6_test_score                                                       0.856008
# split7_test_score                                                       0.626074
# split8_test_score                                                       0.847134
# split9_test_score                                                       0.496299
# mean_test_score                                                         0.598808
# std_test_score                                                          0.215273
# rank_test_score                                                              207
# split0_train_score                                                             1
# split1_train_score                                                             1
# split2_train_score                                                             1
# split3_train_score                                                             1
# split4_train_score                                                             1
# split5_train_score                                                             1
# split6_train_score                                                             1
# split7_train_score                                                             1
# split8_train_score                                                             1
# split9_train_score                                                             1
# mean_train_score                                                               1
# std_train_score                                                                0
#
#                                                                              35   \
# mean_fit_time                                                         0.00214121
# std_fit_time                                                         0.000245023
# mean_score_time                                                       0.00344589
# std_score_time                                                       0.000553699
# param_classifier               KNeighborsRegressor(algorithm='auto', leaf_siz...
# param_classifier__n_neighbors                                                  1
# param_classifier__p                                                            8
# param_classifier__weights                                               distance
# param_preprocessing            RobustScaler(copy=True, quantile_range=(25.0, ...
# params                         {'classifier': KNeighborsRegressor(algorithm='...
# split0_test_score                                                       0.693852
# split1_test_score                                                       0.283455
# split2_test_score                                                       0.444838
# split3_test_score                                                       0.840005
# split4_test_score                                                       0.664806
# split5_test_score                                                       0.238934
# split6_test_score                                                       0.856008
# split7_test_score                                                       0.626074
# split8_test_score                                                       0.847134
# split9_test_score                                                       0.496299
# mean_test_score                                                         0.598808
# std_test_score                                                          0.215273
# rank_test_score                                                              207
# split0_train_score                                                             1
# split1_train_score                                                             1
# split2_train_score                                                             1
# split3_train_score                                                             1
# split4_train_score                                                             1
# split5_train_score                                                             1
# split6_train_score                                                             1
# split7_train_score                                                             1
# split8_train_score                                                             1
# split9_train_score                                                             1
# mean_train_score                                                               1
# std_train_score                                                                0
#
#                                                                              41   \
# mean_fit_time                                                         0.00213737
# std_fit_time                                                         5.41665e-05
# mean_score_time                                                       0.00336626
# std_score_time                                                       0.000459874
# param_classifier               KNeighborsRegressor(algorithm='auto', leaf_siz...
# param_classifier__n_neighbors                                                  1
# param_classifier__p                                                           10
# param_classifier__weights                                               distance
# param_preprocessing            RobustScaler(copy=True, quantile_range=(25.0, ...
# params                         {'classifier': KNeighborsRegressor(algorithm='...
# split0_test_score                                                        0.64225
# split1_test_score                                                       0.259324
# split2_test_score                                                       0.420882
# split3_test_score                                                       0.840005
# split4_test_score                                                       0.664806
# split5_test_score                                                       0.238934
# split6_test_score                                                       0.856008
# split7_test_score                                                       0.634795
# split8_test_score                                                        0.84325
# split9_test_score                                                       0.500714
# mean_test_score                                                         0.589607
# std_test_score                                                           0.21845
# rank_test_score                                                              209
# split0_train_score                                                             1
# split1_train_score                                                             1
# split2_train_score                                                             1
# split3_train_score                                                             1
# split4_train_score                                                             1
# split5_train_score                                                             1
# split6_train_score                                                             1
# split7_train_score                                                             1
# split8_train_score                                                             1
# split9_train_score                                                             1
# mean_train_score                                                               1
# std_train_score                                                                0
#
#                                                                              38
# mean_fit_time                                                         0.00258553
# std_fit_time                                                         0.000706506
# mean_score_time                                                       0.00366466
# std_score_time                                                       0.000620307
# param_classifier               KNeighborsRegressor(algorithm='auto', leaf_siz...
# param_classifier__n_neighbors                                                  1
# param_classifier__p                                                           10
# param_classifier__weights                                                uniform
# param_preprocessing            RobustScaler(copy=True, quantile_range=(25.0, ...
# params                         {'classifier': KNeighborsRegressor(algorithm='...
# split0_test_score                                                        0.64225
# split1_test_score                                                       0.259324
# split2_test_score                                                       0.420882
# split3_test_score                                                       0.840005
# split4_test_score                                                       0.664806
# split5_test_score                                                       0.238934
# split6_test_score                                                       0.856008
# split7_test_score                                                       0.634795
# split8_test_score                                                        0.84325
# split9_test_score                                                       0.500714
# mean_test_score                                                         0.589607
# std_test_score                                                           0.21845
# rank_test_score                                                              209
# split0_train_score                                                             1
# split1_train_score                                                             1
# split2_train_score                                                             1
# split3_train_score                                                             1
# split4_train_score                                                             1
# split5_train_score                                                             1
# split6_train_score                                                             1
# split7_train_score                                                             1
# split8_train_score                                                             1
# split9_train_score                                                             1
# mean_train_score                                                               1
# std_train_score                                                                0
#
# [35 rows x 210 columns]
