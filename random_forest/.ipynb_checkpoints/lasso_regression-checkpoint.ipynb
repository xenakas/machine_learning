# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import KBinsDiscretizer

# %%
data_diamonds = pd.read_csv("diamonds.csv", index_col= 0)

# %%
data_diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
data_diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %%
fig, axes = plt.subplots(7, 1, figsize=(5, 10))
ax = axes.ravel()
for i,j in enumerate([0,4,5,6,7,8,9]):
    f, bins = np.histogram(data_diamonds.iloc[:, j], bins=50)
    ax[i].hist(data_diamonds.iloc[:, j], bins=bins, alpha=.5)
    ax[i].set_title(data_diamonds.columns.values[j])
    ax[i].set_yticks(())
fig.tight_layout()

# %% [markdown]
# ##### Удалим выбросы и нули по x, y, z

# %%
display(data_diamonds[data_diamonds.y>10])
data_wo_out = data_diamonds[data_diamonds.y<=10]
# Out:
#        carat      cut color clarity  depth  table  price      x      y     z
# 24068   2.00  Premium     H     SI2   58.9   57.0  12210   8.09  58.90  8.06
# 25999   4.01  Premium     I      I1   61.0   61.0  15223  10.14  10.10  6.17
# 27416   5.01     Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
# 27631   4.50     Fair     J      I1   65.8   58.0  18531  10.23  10.16  6.72
# 49190   0.51    Ideal     E     VS1   61.8   55.0   2075   5.15  31.80  5.12

# %%
display(data_diamonds[data_diamonds.z>6])
data_wo_out = data_wo_out[data_wo_out.z<=6]
# Out:
#        carat        cut color clarity  depth  table  price      x      y  \
# 23645   3.65       Fair     H      I1   67.1   53.0  11668   9.53   9.48
# 24068   2.00    Premium     H     SI2   58.9   57.0  12210   8.09  58.90
# 24329   3.50      Ideal     H      I1   62.8   57.0  12587   9.65   9.59
# 25999   4.01    Premium     I      I1   61.0   61.0  15223  10.14  10.10
# 26000   4.01    Premium     J      I1   62.5   62.0  15223  10.02   9.94
# 26195   2.01       Fair     G     SI2   65.6   56.0  15562   7.89   7.84
# 26432   3.40       Fair     D      I1   66.8   52.0  15964   9.42   9.34
# 26445   4.00  Very Good     I      I1   63.3   58.0  15984  10.01   9.94
# 26535   3.67    Premium     I      I1   62.4   56.0  16193   9.86   9.81
# 27131   4.13       Fair     H      I1   64.8   61.0  17329  10.00   9.85
# 27416   5.01       Fair     J      I1   65.5   59.0  18018  10.74  10.54
# 27631   4.50       Fair     J      I1   65.8   58.0  18531  10.23  10.16
# 27680   3.51    Premium     J     VS2   62.5   59.0  18701   9.66   9.63
# 48411   0.51  Very Good     E     VS1   61.8   54.7   1970   5.12   5.15
#
#            z
# 23645   6.38
# 24068   8.06
# 24329   6.03
# 25999   6.17
# 26000   6.24
# 26195   6.16
# 26432   6.27
# 26445   6.31
# 26535   6.13
# 27131   6.43
# 27416   6.98
# 27631   6.72
# 27680   6.03
# 48411  31.80

# %%
display(data_diamonds[(data_diamonds['x']==0) | (data_diamonds['y']==0) | (data_diamonds['z']==0)])
data_wo_out = data_wo_out[~(data_wo_out['x']==0) & ~(data_wo_out['y']==0) & ~(data_wo_out['z']==0)]
# Out:
#        carat        cut color clarity  depth  table  price     x     y    z
# 2208    1.00    Premium     G     SI2   59.1   59.0   3142  6.55  6.48  0.0
# 2315    1.01    Premium     H      I1   58.1   59.0   3167  6.66  6.60  0.0
# 4792    1.10    Premium     G     SI2   63.0   59.0   3696  6.50  6.47  0.0
# 5472    1.01    Premium     F     SI2   59.2   58.0   3837  6.50  6.47  0.0
# 10168   1.50       Good     G      I1   64.0   61.0   4731  7.15  7.04  0.0
# 11183   1.07      Ideal     F     SI2   61.6   56.0   4954  0.00  6.62  0.0
# 11964   1.00  Very Good     H     VS2   63.3   53.0   5139  0.00  0.00  0.0
# 13602   1.15      Ideal     G     VS2   59.2   56.0   5564  6.88  6.83  0.0
# 15952   1.14       Fair     G     VS1   57.5   67.0   6381  0.00  0.00  0.0
# 24395   2.18    Premium     H     SI2   59.4   61.0  12631  8.49  8.45  0.0
# 24521   1.56      Ideal     G     VS2   62.2   54.0  12800  0.00  0.00  0.0
# 26124   2.25    Premium     I     SI1   61.3   58.0  15397  8.52  8.42  0.0
# 26244   1.20    Premium     D    VVS1   62.1   59.0  15686  0.00  0.00  0.0
# 27113   2.20    Premium     H     SI1   61.2   59.0  17265  8.42  8.37  0.0
# 27430   2.25    Premium     H     SI2   62.8   59.0  18034  0.00  0.00  0.0
# 27504   2.02    Premium     H     VS2   62.7   53.0  18207  8.02  7.95  0.0
# 27740   2.80       Good     G     SI2   63.8   58.0  18788  8.90  8.85  0.0
# 49557   0.71       Good     F     SI2   64.1   60.0   2130  0.00  0.00  0.0
# 49558   0.71       Good     F     SI2   64.1   60.0   2130  0.00  0.00  0.0
# 51507   1.12    Premium     G      I1   60.4   59.0   2383  6.71  6.67  0.0

# %%
data_wo_out.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53905.000000  53905.000000  53905.000000  53905.000000  53905.000000
# mean       0.797022     61.749025     57.456893   3928.242593      5.730708
# std        0.471617      1.431737      2.233881   3983.527373      1.117866
# min        0.200000     43.000000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    949.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2400.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5320.000000      6.540000
# max        3.240000     79.000000     95.000000  18823.000000      9.540000
#
#                   y             z
# count  53905.000000  53905.000000
# mean       5.732549      3.538790
# std        1.109789      0.690439
# min        3.680000      1.070000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.030000
# max        9.460000      5.980000

# %%
fig, axes = plt.subplots(3, 1, figsize=(10, 5))
ax = axes.ravel()
for i,j in enumerate([7,8,9]):
    f, bins = np.histogram(data_wo_out.iloc[:, j], bins=50)
    ax[i].hist(data_wo_out.iloc[:, j], bins=bins, alpha=.5)
    ax[i].set_title(data_wo_out.columns.values[j])
    ax[i].set_yticks(())
fig.tight_layout()

# %% [markdown]
# ##### Создадим фичи объем и плотность алмаза

# %%
data_wo_out['volume'] = data_wo_out['x']*data_wo_out['y']*data_wo_out['z']

# %%
data_wo_out['density'] = data_wo_out['carat'] /data_wo_out['volume']

# %%
fig, axes = plt.subplots(2, 1, figsize=(10, 5))
ax = axes.ravel()
for i,j in enumerate([-2,-1]):
    f, bins = np.histogram(data_wo_out.iloc[:, j], bins=50)
    ax[i].hist(data_wo_out.iloc[:, j], bins=bins, alpha=.5)
    ax[i].set_title(data_wo_out.columns.values[j])
    ax[i].set_yticks(())
fig.tight_layout()

# %% [markdown]
# ##### Пометим алмазы с сомнительной плотностью

# %%
data_wo_out['bad'] = (data_wo_out['density'] < 0.0055)|(data_wo_out['density'] > 0.007)

# %%
fig, axes = plt.subplots(2, 1, figsize=(10, 5))
ax = axes.ravel()
for i,j in enumerate([-3,-2]):
    f, bins = np.histogram(data_wo_out[data_wo_out['bad'] == False].iloc[:, j], bins=50)
    ax[i].hist(data_wo_out[data_wo_out['bad'] == False].iloc[:, j], bins=bins, alpha=.5)
    ax[i].set_title(data_wo_out[data_wo_out['bad'] == False].columns.values[j])
    ax[i].set_yticks(())
fig.tight_layout()

# %%
data_wo_out['bad'] = pd.get_dummies(data_wo_out['bad'],drop_first=True)

# %% [markdown]
# #### [Создадим факторные переменные  ](https://ggplot2.tidyverse.org/reference/diamonds.html)

# %% [markdown]
# ##### Качество огранки (Fair, Good, Very Good, Premium, Ideal)

# %%
data_wo_out['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
data_wo_out['cut'] = data_wo_out['cut'].replace({'Fair':0, 'Good':1, 'Very Good':2, 'Premium':3, 'Ideal':4})

# %% [markdown]
# ##### Прозрачность (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))

# %%
data_wo_out['clarity'].unique()
# Out:
# array(['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'],
#       dtype=object)

# %%
data_wo_out['clarity'] = data_wo_out['clarity'].replace({'I1':0, 'SI2':1, 'SI1':2, 'VS2':3, 'VS1':4, 'VVS2':5, 'VVS1':6, 'IF':7})

# %% [markdown]
# #####  Цвет (J (worst) to D (best))

# %%
data_wo_out['color'].unique()
# Out:
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)

# %% [markdown]
# ##### [Дамми по группам цвета](https://awesomegems.com/diamondfacts.html)

# %% [markdown]
# -  D-F - the finest & brightest colorless diamonds, usually for the discriminating customer who can afford the most beautiful and the rare.
# - G-H - very white & bright face-up, near colorless diamonds that are not as expensive, and when mounted in jewelry it is difficult to see the the difference between these and the higher color grades.
# - I-J - not quite as bright or have very slight hardly noticeable tint.

# %%
data_wo_out['color_group'] = data_wo_out['color'].replace({'D':2,'E':2,'F':2,'G':1,'H':1,'I':0,'J':0})

# %%
data_wo_out['color'] = data_wo_out['color'].replace({'D':6,'E':5,'F':4,'G':3,'H':2,'I':1,'J':0})

# %%
dumdum = pd.get_dummies(data_wo_out['color_group'], drop_first=True)

# %%
data_wo_out = pd.concat([data_wo_out,dumdum], axis=1)

# %% [markdown]
# #####  Создадим бины по весу

# %%
data_ext = data_wo_out.copy()

# %%
np.array(data_ext['carat']).reshape(1, -1)
# Out:
# array([[0.23, 0.21, 0.23, ..., 0.7 , 0.86, 0.75]])

# %%
kb_ord = KBinsDiscretizer(n_bins=20, strategy='kmeans', encode='ordinal')
kb_ord.fit(data_ext[['carat']])
data_ord = kb_ord.transform(data_ext[['carat']])
data_ord[:5]
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        [0.],
#        [0.]])

# %%
pd.value_counts(pd.Series(data_ord.flatten()))
# Out:
# 0.0     11058
# 5.0      7983
# 2.0      7321
# 3.0      6520
# 1.0      6508
# 6.0      3500
# 4.0      3356
# 8.0      2632
# 7.0      1311
# 11.0     1211
# 9.0       767
# 10.0      757
# 12.0      432
# 13.0      243
# 14.0      143
# 15.0       95
# 18.0       26
# 16.0       24
# 17.0       15
# 19.0        3
# dtype: int64

# %%
data_ext['carat_ord'] = data_ord

# %%
data_ext[data_ext['carat_ord']>=18.0]
# Out:
#        carat  cut  color  clarity  depth  table  price     x     y     z  \
# 16284   3.00    2      2        0   63.1   55.0   6512  9.23  9.10  5.77
# 19340   3.01    3      1        0   62.7   58.0   8040  9.10  8.97  5.67
# 19347   3.00    0      2        0   67.1   57.0   8044  8.93  8.84  5.97
# 21759   3.11    0      0        0   65.9   57.0   9823  9.15  9.02  5.98
# 21863   3.01    3      4        0   62.2   56.0   9925  9.24  9.13  5.73
# 22429   3.05    3      5        0   60.9   58.0  10453  9.26  9.25  5.66
# 22541   3.02    0      1        0   65.2   56.0  10577  9.11  9.02  5.91
# 22742   3.01    0      2        0   56.1   62.0  10761  9.54  9.38  5.31
# 22832   3.00    1      1        0   57.0   64.0  10863  9.38  9.31  5.33
# 23540   3.00    1      5        0   64.2   65.0  11548  9.08  8.96  5.79
# 24132   3.24    3      2        0   62.1   58.0  12300  9.44  9.40  5.85
# 24298   3.22    4      1        0   62.6   55.0  12545  9.49  9.42  5.92
# 24817   3.00    3      3        0   59.7   60.0  13203  9.42  9.26  5.58
# 25461   3.01    3      3        1   59.8   58.0  14220  9.44  9.37  5.62
# 25851   3.00    1      0        1   59.3   64.0  14918  9.32  9.19  5.50
# 26101   3.04    2      1        1   63.2   59.0  15354  9.14  9.07  5.75
# 26468   3.01    4      0        1   61.7   58.0  16037  9.25  9.20  5.69
# 26745   3.01    4      0        0   65.4   60.0  16538  8.99  8.93  5.86
# 26933   3.00    3      1        1   60.7   59.0  16970  9.30  9.14  5.60
# 26934   3.00    0      1        1   64.8   59.0  16970  8.93  8.73  5.72
# 27515   3.01    3      1        1   60.2   59.0  18242  9.36  9.31  5.62
# 27516   3.01    0      1        1   65.8   56.0  18242  8.99  8.94  5.90
# 27517   3.01    0      1        1   65.8   56.0  18242  8.99  8.94  5.90
# 27518   3.01    1      1        1   63.9   60.0  18242  9.06  9.01  5.77
# 27519   3.01    1      1        1   63.9   60.0  18242  9.06  9.01  5.77
# 27639   3.04    3      1        1   59.3   60.0  18559  9.51  9.46  5.62
# 27650   3.01    1      2        1   57.6   64.0  18593  9.44  9.38  5.42
# 27685   3.01    3      0        1   60.7   59.0  18710  9.35  9.22  5.64
# 27686   3.01    3      0        1   59.7   58.0  18710  9.41  9.32  5.59
#
#            volume   density  bad  color_group  1  2  carat_ord
# 16284  484.639610  0.006190    0            1  1  0       18.0
# 19340  462.825090  0.006504    0            0  0  0       18.0
# 19347  471.278964  0.006366    0            1  1  0       18.0
# 21759  493.547340  0.006301    0            0  0  0       19.0
# 21863  483.389676  0.006227    0            2  0  1       18.0
# 22429  484.807300  0.006291    0            2  0  1       18.0
# 22541  485.637702  0.006219    0            0  0  0       18.0
# 22742  475.166412  0.006335    0            1  1  0       18.0
# 22832  465.457174  0.006445    0            0  0  0       18.0
# 23540  471.055872  0.006369    0            2  0  1       18.0
# 24132  519.105600  0.006242    0            1  1  0       19.0
# 24298  529.223136  0.006084    0            0  0  0       19.0
# 24817  486.738936  0.006163    0            1  1  0       18.0
# 25461  497.104736  0.006055    0            1  1  0       18.0
# 25851  471.079400  0.006368    0            0  0  0       18.0
# 26101  476.673850  0.006378    0            0  0  0       18.0
# 26468  484.219000  0.006216    0            0  0  0       18.0
# 26745  470.444902  0.006398    0            0  0  0       18.0
# 26933  476.011200  0.006302    0            0  0  0       18.0
# 26934  445.924908  0.006728    0            0  0  0       18.0
# 27515  489.735792  0.006146    0            0  0  0       18.0
# 27516  474.186540  0.006348    0            0  0  0       18.0
# 27517  474.186540  0.006348    0            0  0  0       18.0
# 27518  471.008562  0.006391    0            0  0  0       18.0
# 27519  471.008562  0.006391    0            0  0  0       18.0
# 27639  505.601052  0.006013    0            0  0  0       18.0
# 27650  479.925824  0.006272    0            1  1  0       18.0
# 27685  486.207480  0.006191    0            0  0  0       18.0
# 27686  490.249708  0.006140    0            0  0  0       18.0

# %%
data_ext.shape
# Out:
# (53905, 17)

# %% [markdown]
# #####  Создадим полиномиальные фичи

# %%
num_feat = ['carat', 'volume', 'density', 'depth', 'table']

# %%
for i in num_feat:
    data_ext[i+'_log'] = np.log(data_ext[i])

# %%
poly = PolynomialFeatures(degree=3, include_bias=False)
poly.fit(data_ext[num_feat])
data_poly = poly.transform(data_ext[num_feat])
data_poly = pd.DataFrame(data_poly)
data_poly.columns = poly.get_feature_names()
data_poly.index = data_ext.index

# %%
data_ext = pd.concat([data_ext, data_poly.iloc[:,5:]], axis=1)

# %% [markdown]
# #### RANDOM FOREST

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=42)
